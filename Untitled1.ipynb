# %%
n = int(input("Enter a number:"))
total = 0
i = 1
while i <= n:
    total = total + i
    i = i + 1
print("Sum from 1 to", n, "is", total)
# Out:
# Enter a number:  64
# Sum from 1 to 64 is 2080

# %%
n = 77
total = 0
i = 1
while i <= n:
    total = total + i
    i = i + 1
print("Sum from 1 to", n, "is", total)
# Out:
# Sum from 1 to 77 is 3003

# %%
Write a program to reverse a given integer number mathematically.
