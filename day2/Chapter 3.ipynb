# %% [markdown]
# # Chapter 3: Loops and conditions
#
# <h2 style="color: #1f4acc; text-decoration: underline;">
# 3.1 For loops
# </h2>
#
# Up to now, we’ve seen that a **calendar can be represented as a dictionary**. For example:
#
# ```python
# d = {
#     "Monday": "Gym",
#     "Tuesday": "Bioinformatics",
#     "Wednesday": "Basketball"
# }
# ```
# But what happens if we want to see all the activities?
# **Could we check them one by one?**
#
# ---
# **Українською:** Chapter 3: цикли та умовні оператори. Тут пояснюються словники Python: доступ за ключем, додавання, оновлення, видалення елементів і вкладені словники.

# %%
d = {
    "Monday": "Gym",
    "Tuesday": "Bioinformatics",
    "Wednesday": "Basketball"
}

# Checking each day of the calendar
print(d["Monday"])
print(d["Tuesday"])
print(d["Wednesday"])

# %% [markdown]
# This works... but is it practical?
#
# * <h5 style="color: red; text-decoration: underline;"> Not scalable </h5>
# * <h5 style="color: red; text-decoration: underline;"> Repetitive </h5>
# * <h5 style="color: red; text-decoration: underline;"> Impossible to manage with many items </h5>
#
# So what do we need? --> We need a way to **go through all the items automatically**.
#
# In programming, this is called **iteration**.
#
# <h4 style="color: orange; text-decoration: underline;">
# Defining an Iteration
# </h4>
#
# **Iterating** is the process of going through each element of a collection, one by one. In our example:
#
# ![image.png](attachment:bc56560f-233b-4144-8314-f72f2759b727.png)
#
# Instead of accessing each item manually, we move through all of them automatically. We are visiting every item in the collection.
#
# #### ---- Let's do an example! ----
#
# We want to iterate through the days of our calendar.
#
# ---
# **Українською:** This works... but is it practical?. Тут пояснюється ітерація: як цикл `for` автоматично проходить по елементах списку або словника.

# %%
calendar = {
    "Monday": "Gym",
    "Tuesday": "Bioinformatics",
    "Wednesday": "Basketball"
}

for day in calendar:
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday

# %% [markdown]
# ### What is happening here?
#
# - `for` → starts a loop
# - `day` → is a variable that takes one key at a time
# - `in calendar` → means we go through all the keys in the dictionary
#
# Iteration step by step:
#
# 1. day = "Monday" → print("Monday")
# 2. day = "Tuesday" → print("Tuesday")
# 3. day = "Wednesday" → print("Wednesday")
#
# The loop automatically visits each key in the dictionary.
#
# <h4 style="color: red; text-decoration: underline;">
# Question: How can we access the activity of each day while iterating?
# </h4>
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
# Write here the answer

# %% [markdown]
# #### Maybe we want to access both key and values at the same time. To access both the **day** and the **activity** at the same time, we can use:
#
# ---
# **Українською:** Maybe we want to access both key and values at the same time. To access both the day and the activity at the same time, we can use:. Цей розділ пояснює цикли та умовні оператори: як проходити по списках і словниках, використовувати `for` і `while`, перевіряти умови за допомогою `if`, `else` та `elif`, а також виконувати вправи з послідовностями.

# %%
for day, activity in calendar.items():
    print(day, activity)
# Out:
# Monday Gym
# Tuesday Bioinformatics
# Wednesday Basketball

# %% [markdown]
# ### What is happening here?
#
# - `calendar.items()` returns **pairs of (key, value)**
# - `day` → stores the key
# - `activity` → stores the value
#
# At each iteration, we get both elements at the same time. Iteration step by step:
#
# ("Monday", "Gym")
# ("Tuesday", "Bioinformatics")
# ("Wednesday", "Basketball")
#
# **So at each step:**
#
# day = "Monday", activity = "Gym"
# day = "Tuesday", activity = "Bioinformatics"
# day = "Wednesday", activity = "Basketball"
#
# <h4 style="color: orange; text-decoration: underline;">
# For loops in lists
# </h4>
#
# So far, we have used `for` loops with dictionaries. But we can iterate through **other types of data collections** as well.
#
# #### ---- Let's do an example! ----
#
# We want to iterate through the items of our shopping list.
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
shopping_l = ["apple", "banana", "chocolate"]

for item in shopping_l:
    print(item)
# Out:
# apple
# banana
# chocolate

# %% [markdown]
# ### What is happening here?
#
# - `item` takes each element of the list, one by one
# - The loop goes through all elements in order
#
# **Iteration step by step:**
#
# item = "apple" → print("apple")
# item = "banana" → print("banana")
# item = "chocolate" → print("chocolate")
#
# <h4 style="color: red; text-decoration: underline;">
# Question: What will happen if we do print(item.upper())?
# </h4>
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
# Answer here

# %% [markdown]
# Talk about looping and index
#
# ---
# **Українською:** Talk about looping and index. Цей розділ пояснює цикли та умовні оператори: як проходити по списках і словниках, використовувати `for` і `while`, перевіряти умови за допомогою `if`, `else` та `elif`, а також виконувати вправи з послідовностями.

# %% [markdown]
# <h2 style="color: #1f4acc; text-decoration: underline;">
# 3.2 While loops
# </h2>
#
# In python there are also while loops. They are used to execute a block of statements repeatedly until a given condition is satisfied. When the condition becomes false, the line immediately after the loop in the program is executed.
#
# #### ---- Let's do an example! ----
# We are going to create a while loop which will be iterating until the counter reaches three
#
# ---
# **Українською:** Тут пояснюється цикл `while`: код повторюється, доки умова істинна, тому важливо змінювати умову всередині циклу.

# %%
cnt = 0 
while (cnt < 3):
    cnt = cnt+1
    print("Hello Guys")

# %% [markdown]
# ### What is happening here?
#
# - We start with `cnt = 0`
# - The loop runs **while `cnt < 3`**
#
# **Iteration step by step:**
#
# 1. cnt = 0 → condition is True → print → cnt = 1
# 2. cnt = 1 → condition is True → print → cnt = 2
# 3. cnt = 2 → condition is True → print → cnt = 3
# 4. cnt = 3 → condition is False → loop stops
#
# #### ---- Let's do another example! ----
# Execute the following piece of code. What is happening now?
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
cnt = 0

while cnt < 3:
    print("Hello")

# %% [markdown]
# ### What happens here?
#
# <h5 style="color: red; text-decoration: underline;">
# The loop will never stop (infinite loop)
# </h5>
#
# Why?
#
# - `cnt` never changes
# - The condition is always True
#
# 👉 Always make sure the condition will eventually become False
#
# <h4 style="color: red; text-decoration: underline;">
# Questions:
#
# - What happens if we start with `cnt = 5`?
# - How many times will the loop run?
# </h4>
#
# ---
# **Українською:** What happens here?. Це завдання для самостійної практики: прочитайте умову, виконайте кроки в коді та перевірте результат.

# %%
# Try code here and answer

# %% [markdown]
# ![image.png](attachment:2536559c-5856-4bcc-b622-c64d5e80948a.png)
#
# ---
# **Українською:** ![image.png](attachment:2536559c-5856-4bcc-b622-c64d5e80948a.png). Цей розділ пояснює цикли та умовні оператори: як проходити по списках і словниках, використовувати `for` і `while`, перевіряти умови за допомогою `if`, `else` та `elif`, а також виконувати вправи з послідовностями.

# %% [markdown]
# <h2 style="color: #1f4acc; text-decoration: underline;">
# 3.3 Conditional statements
# </h2>
#
# Conditional statements are used to execute certain blocks of code based on specific conditions. Imagine you are at the supermarket:
#
# 👉 Is this chocolate?
#
# - YES → Buy it 🍫
# - NO → Don't buy it ❌
#
# **How can we translate this into python?**
#
# ---
# **Українською:** Тут пояснюються умовні оператори: `if`, `else` та `elif` дозволяють виконувати різний код залежно від умови.

# %%
l = ["chocolate","banana","apple"]
for food in l:
    if food == "chocolate":
        print("Buy",food)

# %% [markdown]
# ### What is happening here?
#
# for each product in the shopping list we're checking:
# - `if` → checks a condition
# - `food == "chocolate"` → is the condition
# - If condition is True -> Then buying the food item
#
# #### Think of it like a decision tree:
#
#         condition?
#         /       \
#       YES       NO
#       ↓          ↓
#     do this  do something else
#
# ----
#
# <h4 style="color: orange; text-decoration: underline;">
# If/else conditions
# </h4>
# Allows us to specify a block of code that will execute if the condition associated with an if statement evaluates to False.
#
# 👉 Is this chocolate?
#
# * YES → Buy it 🍫
# * NO → Don't buy it ❌ (else)
#
# #### ---- Let's do an example! ----
# If food is chocolate we will buy it, if not we won't buy it
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
l = ["chocolate","banana","apple"]
for food in l:
    if food == "chocolate":
        print("Buy",food)
    else:
        print("Not buying",food)

# %% [markdown]
# ### What is happening here?
#
# - We iterate through the list using a `for` loop
# - For each element (`food`), we check a condition
# - If `food == "chocolate"` → we print "Buy"
# - Otherwise (`else`) → we print "Not buying"
#
# **Iteration step by step:**
#
# food = "chocolate" → Buy chocolate 🍫
# food = "banana" → Not buying banana ❌
# food = "apple" → Not buying apple ❌
#
# ----
#
# <h4 style="color: orange; text-decoration: underline;">
# elif conditions
# </h4>
# Stands for “else if”. Allows us to check multiple conditions, providing a way to execute different blocks of code based on which condition is true
#
# 👉 Is this chocolate?
#
# - YES → Buy it 🍫
#
# 👉 NO → Is this banana?
#
# - YES → Buy it 🍌
#
# 👉 NO → Don't buy it ❌ (else)
#
#
# **Think of it like a chain of decisions:**
#
#     * if → first condition
#     * elif → second condition
#     * elif → third condition
#     * else → none of the above
#
# #### ---- Let's do an example! ----
# If food is chocolate we will buy it, if it is not but it is banana we will still buy it, but if none of these two are we won't buy it
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %%
l = ["chocolate","banana","apple"]
for food in l:
    if food == "chocolate":
        print("Buy",food)
    elif food == "banana":
        print("Buy",food)
    else:
        print("Not buying",food)

# %% [markdown]
# ### What is happening here?
#
# - For each `food`, Python checks conditions in order:
#
# 1. Is it `"chocolate"`?
# 2. If not → is it `"banana"`?
# 3. If none are true → go to `else`
#
# **Iteration step by step:**
#
# food = "chocolate" → Buy chocolate 🍫
# food = "banana" → Buy banana 🍌
# food = "apple" → Not buying apple ❌
#
# ---
# **Українською:** що тут відбувається?. У цьому поясненні розбирається, що саме робить попередній код, які обʼєкти створюються та чому результат виглядає саме так.

# %% [markdown]
# <h2 style="color: #1f4acc; text-decoration: underline;">
# 3.4 Exercices
# </h2>
#
# ### Exercise 1
#
# You are given a list of DNA sequences:
#
# ```python
# seqs = ["ATGCGT", "TTAGGC", "CCGTAA"]
# ```
#
# #### Tasks:
#
# 1. Print only sequences longer than 6
# 2. Print only sequences that contain "GG"
#
# ---
# **Українською:** У вправі потрібно працювати зі списком ДНК-послідовностей: вибирати елементи, перевіряти довжину, шукати підрядки або змінювати структуру даних.

# %%
# Write your answer here
seqs = ["ATGCGT", "TTAGGC", "CCGTAAC"]
for dna in seqs:
    if len(dna)>6:
        print(f"Sequence longer then 6: ", dna)
for dna in seqs:        
    if 'GG' in dna:
        print(dna)
# Out:
# Sequence longer then 6:  CCGTAAC
# TTAGGC

# %% [markdown]
# ### Exercise 2
#
# You are given a list of sequences:
#
# ```
# seqs = ["ATGCGT", "TTAGGC", "CCGTAA"]
# ````
#
# #### Task:
#
# Create a dictionary where:
# - keys → "seq1", "seq2", ...
# - values → sequences
#
# Expected output:
# {"seq1": "ATGCGT", "seq2": "TTAGGC", ...}
#
# ---
# **Українською:** вправа 2. Це завдання для самостійної практики: прочитайте умову, виконайте кроки в коді та перевірте результат.

# %%
# Write your answer here
seqs = ["ATGCGT", "TTAGGC", "CCGTAA"]
seqs_dict={}
cnt=0
for dna in seqs:
    cnt=cnt+1
    seqs_dict[f'seq{cnt}'] = dna

print(seqs_dict)
# Out:
# {'seq1': 'ATGCGT', 'seq2': 'TTAGGC', 'seq3': 'CCGTAA'}

# %% [markdown]
# ### Exercise 3
#
# You are given:
#
# ````
# seqs = ["ATG", "ATGCGT", "TTA", "CCGTAA", "GG"]
# ````
#
# #### Task:
#
# Create a dictionary that counts how many sequences have each length.
#
# ---
# **Українською:** вправа 3. Це завдання для самостійної практики: прочитайте умову, виконайте кроки в коді та перевірте результат.

# %%
# Write your answer here
seqs = ["ATG", "ATGCGT", "TTA", "CCGTAA", "GG"]
seqs_dict2={}
lengths= []
for seq in seqs:
    l = len(seq)
    lengths.append(l)
for seq in lengths:
    if seq in seqs_dict2:
        seqs_dict2[seq]=seqs_dict2[seq]+1
    else:
        seqs_dict2[seq]=1
print(seqs_dict2)
# Out:
# {3: 2, 6: 2, 2: 1}

# %% [markdown]
# ### Exercise 4
#
# You are given:
#
# ````
# fasta = {
#     "seq1": {"sequence": "ATGCGT", "length": 6},
#     "seq2": {"sequence": "TTAGGCA", "length": 7},
#     "seq3": {"sequence": "CCGTAA", "length": 6}
# }
# ````
#
# #### Tasks:
#
# 1. Print only sequences with length > 6
# 2. Print the name of the sequence that contains "GG"
# 3. Count how many sequences satisfy BOTH conditions
#
# ---
# **Українською:** вправа 4. У вправі потрібно працювати з FASTA-подібними даними: розбирати заголовки, групувати послідовності, рахувати GC-вміст і знаходити потрібні гени або послідовності.

# %%
# Write your answer here
fasta = {
    "seq1": {"sequence": "ATGCGT", "length": 6},
    "seq2": {"sequence": "TTAGGCA", "length": 7},
    "seq3": {"sequence": "CCGTAA", "length": 6}
}
for seq in fasta[seq]:
    if fasta[seq]['length']>6:
        print(fasta[seq]['sequence'])
    if 'GG' in fasta[seq]['sequence']:
        print(fasta[seq]['sequence'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 7
#       3     "seq1": {"sequence": "ATGCGT", "length": 6},
#       4     "seq2": {"sequence": "TTAGGCA", "length": 7},
#       5     "seq3": {"sequence": "CCGTAA", "length": 6}
#       6 }
# ----> 7 for seq in fasta[seq]:
#       8     if fasta[seq]['length']>6:
#       9         print(fasta[seq]['sequence'])
#      10     if 'GG' in fasta[seq]['sequence']:
#
# KeyError: 2

# %% [markdown]
# ### Exercise 5 — FASTA deep analysis
#
# You are given a FASTA-like dictionary:
#
# ````
# fasta = {
#     "seq1|human|geneA": "ATGCGTAGGCTA",
#     "seq2|mouse|geneB": "TTAGGCGG",
#     "seq3|human|geneC": "CCGTAA",
#     "seq4|yeast|geneD": "GGGGGGGG",
#     "seq5|human|geneE": "ATATATAT",
#     "seq6|mouse|geneF": "CGCGCGTA"
# }
# ````
#
#
# Each header has the format:
# "seqX|species|gene"
#
# ### Tasks:
#
# 1. Create a dictionary that counts how many sequences belong to each species
#    Expected: {"human": ?, "mouse": ?, "yeast": ?}
#
# 2. Find the **longest sequence for each species**
#    Expected: {"human": "...", "mouse": "...", ...}
#
# 3. Print only sequences that:
#    - belong to "human"
#    - AND have more than 50% GC content
#
# 4. Find the **gene name** of the sequence with the highest GC content
#
# ---
#
# ### ⚠️ Rules:
#
# - You must parse the header using string operations
# - You must NOT hardcode species or gene names
# - You must compute GC content manually
#
# ---
# **Українською:** вправа 5 — FASTA deep analysis. У вправі потрібно працювати з FASTA-подібними даними: розбирати заголовки, групувати послідовності, рахувати GC-вміст і знаходити потрібні гени або послідовності.

# %%
# Write your answer here

# %% [markdown]
# ### Exercise 6 — Complex filtering and reconstruction
#
# You are given a nested structure:
#
# ```
# data = {
#     "sample1": {
#         "seq1": "ATGCGTAA",
#         "seq2": "GGGGTTTT",
#         "seq3": "ATATATAT"
#     },
#     "sample2": {
#         "seq4": "CCCGGG",
#         "seq5": "TTTTAAA",
#         "seq6": "GGATCC"
#     },
#     "sample3": {
#         "seq7": "ATGCGCGC",
#         "seq8": "AAAAAAA",
#         "seq9": "CGT"
#     }
# }
# ```
#
# ---
#
# ### Tasks:
#
# 1. Create a **new dictionary** that only contains sequences that:
#    - have length ≥ 6
#    - AND contain at least one "G"
#
#  Keep the same structure (sample → sequences)
#
# ---
#
# 2. For each sample:
#    - count how many sequences passed the filter
#
#  Expected:
# {"sample1": X, "sample2": Y, ...}
#
# ---
#
# 3. Find the **sample with the highest average sequence length**
#
# ---
#
# 4. Create a **set** with all unique sequences across all samples
#
# ---
#
# 5. BONUS:
# Create a dictionary grouping sequences by GC content:
#
# Example:
# {
#   "high_GC": [...],
#   "low_GC": [...]
# }
#
# (Define your own threshold, e.g., >50%)
#
# ---
#
# ### ⚠️ Rules:
#
# - You must use nested loops
# - You must NOT flatten the structure first
# - You must compute everything dynamically
#
# ---
# **Українською:** вправа 6 — Complex filtering and reconstruction. Це завдання для самостійної практики: прочитайте умову, виконайте кроки в коді та перевірте результат.

# %%
# Write your answer here
