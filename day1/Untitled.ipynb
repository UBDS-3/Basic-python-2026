# %%
a=16
b=18
print( a+b, a-b, a/b, b*a, a//b, a%b, a**b)
# Out:
# 34 -2 0.8888888888888888 288 0 16 4722366482869645213696

# %%
20//3
# Out:
# 6

# %%
20/3
# Out:
# 6.666666666666667

# %%
20%3
# Out:
# 2

# %%
trying='MASos'

# %%
print(trying[0:3])
# Out:
# MAS

# %%
a=10

# %%
print(not a)
# Out:
# False

# %%
b=False
print(not b)
# Out:
# True

# %%
list_play=[1,2,"Python", "R", "10", False]

# %%
print(list_play[1], list_play[4])
# Out:
# 2 10

# %%
print(list_play[1:5:2])
# Out:
# [2, 'R']

# %%
python_dict={'func':['round','int','del','append'], 
'rate':[10,10,4,0]}
print('Function: ',python_dict['func'][1])
python_dict['rate'][3]=12
print(python_dict['rate'])
print(python_dict)
# Out:
# Function:  int
# [10, 10, 4, 12]
# {'func': ['round', 'int', 'del', 'append'], 'rate': [10, 10, 4, 12]}

# %%
def multiply_numbers(x,y,z):
    a=(x*y*z)
    return a
final= multiply_numbers(4,5,8)
print(final)
# Out:
# 160

# %%
seqs = ["ATGCGT", "TTAGGC", "CCGTAA"]
print(seqs[0])
# Out:
# ATGCGT

# %%
print(seqs[-1])
# Out:
# CCGTAA
