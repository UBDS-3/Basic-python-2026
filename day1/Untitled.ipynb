# %%
1+1
# Out:
# 2

# %%
22+23
# Out:
# 45

# %%
dfr=11+23
dfr+34
# Out:
# 68

# %% [markdown]
# a jupyter tutorial

# %%
var = 10
var
# Out:
# 10

# %%
print(var)
# Out:
# 10

# %%
var = "Hello"
print (var)
# Out:
# Hello

# %%
a = 20
b = 17
calculation = a ** b + b/a - a % b
print("Resault =", calculation)
# Out:
# Resault = 1.31072e+22

# %%
resault = 1.31072e+22
resault / b**a
# Out:
# 0.0032250132161671433

# %%
word = "macaroons"
print("the word:", word)
print("first letter:", word[0])
print("lenght:", len (word))
# Out:
# the word: macaroons
# first letter: m
# lenght: 9

# %%
text = "oportunity"
print(text)
print(text.upper())
print(text.strip().capitalize())
print(text.replace("unity", "destroy"))
# Out:
# oportunity
# OPORTUNITY
# Oportunity
# oportdestroy

# %%
list_play=[1, 2, "Python", "R", "10", False]
list = [ list_play[0], list_play[4] ]
print(list)
# Out:
# [1, '10']

# %%
python_dict= {"func" : ["round", "int", "del", "append"], "rate": [10,10,4,0]}

# %%
def multiply(x, y, z):
    result = x*y*z
    return result
multiply(2, 4, 6)
what = multiply(2, 4, 6)
print ("result =", what)
# Out:
# result = 48
