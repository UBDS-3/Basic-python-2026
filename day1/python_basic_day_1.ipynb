# %% [markdown]
# Day 1. Logic, Syntax, and Data Types of Python
# ====================================
#
# _Python basics for UBDS^2026, 13-17 July 2026, Uzhhorod, Ukraine_
#
# Plan:
# - Installation and setup, conda environments
# - Jupyther notebooks
# - Variables and operators
# - Int and float
# - Strings
# - Lists and tuples
# - Dictionaries
# - Functions and OOP

# %% [markdown]
# Simple Data Types
# ----------------
# - Integers (`int`)
# - Floating-point numbers (`float`)
# - Strings (`str`)
# - Booleans (`bool`)

# %% [markdown]
# ### Numrecial data types: `int` and `float`
# - `int` (integer) represents whole numbers, both positive and negative, without a decimal point. Examples: `-3`, `0`, `42`.
# - `float` (floating-point number) represents real numbers, which can include a decimal point. Examples: `3.14`, `-0.001`, `2.0`.

# %%
# Creating integers and floats

# %%
# Operations on integers and floats

# %% [markdown]
# ### Strings (`str`)
# - A string is a sequence of characters enclosed in single quotes (`'...'`) or double quotes (`"..."`).

# %%
# Creationg and operations on strings

# %%
# Methods for strings

# %% [markdown]
# ### Boolean data type (`bool`)
# - Represents truth values: `True` and `False`.
# - Used for logical operations and control flow.

# %% [markdown]
# Sequence and Mapping Types
# --------------------------
#
# - Lists and nested lists (`list`)
# - Methods for lists
# - Operations on lists
# - Tuples (`tuple`)
# - Dictionaries (`dict`)
# - Methods for dictionaries

# %% [markdown]
# Functions and Object-Oriented Programming Concepts
# --------------------------------------------
#
# - Concepts of functions
# - Syntax of function definition and calling (`def`)
# - Parameters and arguments
# - Return values (`return`)
# - Object-oriented programming (OOP) concepts
# - Classes and objects
# - Methods and attributes

# %% [markdown]
# Exercises and Materials
# -------------------
